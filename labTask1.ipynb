# %%
name = 'Navin'
age = 56
city = 'Ohayo'
formatstring = 'My name is {}. I am {} years old and I live in {}.'.format(name,age,city)
formatstring
# Out:
# 'My name is Navin. I am 56 years old and I live in Ohayo.'

# %%
digit = int(input('Enter a number: '))
last = digit%10

if last%3 == 0:
  print('The number is divisible by 3')
else:
  print('The number is not divisible by 3')
# Out:
# Enter a number: 9
# The number is divisible by 3

# %%
price = int(input('Enter the price of the product: '))

if price>100000:
  price = price + price*0.15
  print("You have to pay: {}".format(price))
elif price>50000 and price<=100000:
  price = price + price*0.10
  print("You have to pay: {}".format(price))
else:
  price = price + price*0.05
  print("You have to pay: {}".format(price))
# Out:
# Enter the price of the product: 5000
# You have to pay: 5250.0

# %%
workingDay = int(input('Enter the number of working days: '))
absent = int(input('Enter total num of days for absent: '))

percentage = (workingDay-absent)/workingDay *100
print(percentage)
if percentage<75:
  print('You are not allowed to sit in exam')
else:
  print('You are allowed to sit in exam')
# Out:
# Enter the number of working days: 10
# Enter total num of days for absent: 5
# 50.0
# You are not allowed to sit in exam
